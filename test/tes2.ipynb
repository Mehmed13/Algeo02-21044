# %%
from matplotlib import pyplot as plt
from matplotlib.image import imread
import cv2 as cv2
import numpy as np
import os

# %%
TRAIN_IMG_FOLDER="./pins_Taylor Swift/"
height = 256
width = 256
train_set_files = os.listdir(TRAIN_IMG_FOLDER)

train_id_file = set([f.split('_')[0] for f in train_set_files])

# %%
print('Train Images:')
train_image_names = os.listdir(TRAIN_IMG_FOLDER)
training_tensor   = np.ndarray(shape=(len(train_image_names), height*width), dtype=np.float64)

for i in range(25):
    # img = cv2.imread(TRAIN_IMG_FOLDER + train_image_names[i])
    # resized = cv2.resize(img, (256,256))
    image = cv2.imread(TRAIN_IMG_FOLDER + train_image_names[i],cv2.IMREAD_GRAYSCALE)
    resized = cv2.resize(image, (256,256))
    print("shape resize")
    print(resized.shape)
    print()
    training_tensor[i,:] = np.array(resized, dtype='float64').flatten()
    plt.subplot(5,5,1+i)
    plt.imshow(image, cmap='gray')
    plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()
# Out:
# Train Images:
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)
#
# shape resize
# (256, 256)

# %%
mean_face = np.zeros((1,height*width))

for i in training_tensor:
    mean_face = np.add(mean_face,i)

mean_face = np.divide(mean_face,float(len(train_image_names))).flatten()

plt.imshow(mean_face.reshape(height, width), cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

normalised_training_tensor = np.ndarray(shape=(len(train_image_names), height*width))

for i in range(len(train_image_names)):
    normalised_training_tensor[i] = np.subtract(training_tensor[i],mean_face)

for i in range(25):
    img = normalised_training_tensor[i].reshape(height,width)
#     plt.subplot(5,5,1+i)
#     plt.imshow(img, cmap='gray')
#     plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
# plt.show()

# %%
normalised_training_tensor = np.ndarray(shape=(len(train_image_names), height*width))

for i in range(25):
    print("shape train")
    print(training_tensor[i].shape)
    print(training_tensor[i])
    print("shape mean face")
    print(mean_face.shape)
    print(mean_face)
    normalised_training_tensor[i] = np.subtract(training_tensor[i],mean_face)
    print("normalied")
    print(normalised_training_tensor[i])
# for i in range(25):
    # img = normalised_training_tensor[i].reshape(height,width)
    plt.subplot(5,5,1+i)
    plt.imshow(normalised_training_tensor[i].reshape(height,width), cmap='gray')
    plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()
# Out:
# shape train
# (65536,)
# [248. 250. 251. ... 193. 198. 178.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [217.97709924 219.96183206 221.         ... 169.35114504 174.85496183
#  155.25954198]
# shape train
# (65536,)
# [231. 231. 231. ... 168. 156. 133.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [200.97709924 200.96183206 201.         ... 144.35114504 132.85496183
#  110.25954198]
# shape train
# (65536,)
# [253. 253. 253. ...  42.  26.  22.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [222.97709924 222.96183206 223.         ...  18.35114504   2.85496183
#   -0.74045802]
# shape train
# (65536,)
# [122. 122. 122. ...  67.  64.  63.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [91.97709924 91.96183206 92.         ... 43.35114504 40.85496183
#  40.25954198]
# shape train
# (65536,)
# [248. 247. 246. ... 205. 204. 203.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [217.97709924 216.96183206 216.         ... 181.35114504 180.85496183
#  180.25954198]
# shape train
# (65536,)
# [166. 168. 170. ...  53.  70.  86.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [135.97709924 137.96183206 140.         ...  29.35114504  46.85496183
#   63.25954198]
# shape train
# (65536,)
# [142. 142. 142. ... 157. 162. 164.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [111.97709924 111.96183206 112.         ... 133.35114504 138.85496183
#  141.25954198]
# shape train
# (65536,)
# [61. 62. 62. ... 32. 19. 22.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [30.97709924 31.96183206 32.         ...  8.35114504 -4.14503817
#  -0.74045802]
# shape train
# (65536,)
# [242. 241. 241. ... 116.  69.  46.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [211.97709924 210.96183206 211.         ...  92.35114504  45.85496183
#   23.25954198]
# shape train
# (65536,)
# [146. 147. 153. ... 107. 108. 108.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [115.97709924 116.96183206 123.         ...  83.35114504  84.85496183
#   85.25954198]
# shape train
# (65536,)
# [160. 174. 169. ...  98.  98.  98.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [129.97709924 143.96183206 139.         ...  74.35114504  74.85496183
#   75.25954198]
# shape train
# (65536,)
# [ 67.  51.  49. ... 193. 198. 200.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [ 36.97709924  20.96183206  19.         ... 169.35114504 174.85496183
#  177.25954198]
# shape train
# (65536,)
# [209. 209. 207. ... 184. 191. 193.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [178.97709924 178.96183206 177.         ... 160.35114504 167.85496183
#  170.25954198]
# shape train
# (65536,)
# [229. 229. 228. ... 215. 221. 223.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [198.97709924 198.96183206 198.         ... 191.35114504 197.85496183
#  200.25954198]
# shape train
# (65536,)
# [231. 231. 232. ... 212. 210. 210.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [200.97709924 200.96183206 202.         ... 188.35114504 186.85496183
#  187.25954198]
# shape train
# (65536,)
# [ 76.  76.  77. ... 125. 122. 120.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [ 45.97709924  45.96183206  47.         ... 101.35114504  98.85496183
#   97.25954198]
# shape train
# (65536,)
# [205. 205. 205. ...  84.  67.  61.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [174.97709924 174.96183206 175.         ...  60.35114504  43.85496183
#   38.25954198]
# shape train
# (65536,)
# [160. 159. 159. ... 179. 179. 179.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [129.97709924 128.96183206 129.         ... 155.35114504 155.85496183
#  156.25954198]
# shape train
# (65536,)
# [ 83.  82.  82. ...  90. 107. 119.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [52.97709924 51.96183206 52.         ... 66.35114504 83.85496183
#  96.25954198]
# shape train
# (65536,)
# [233. 233. 232. ... 123. 106. 102.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [202.97709924 202.96183206 202.         ...  99.35114504  82.85496183
#   79.25954198]
# shape train
# (65536,)
# [68. 74. 88. ... 66. 61. 59.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [37.97709924 43.96183206 58.         ... 42.35114504 37.85496183
#  36.25954198]
# shape train
# (65536,)
# [ 34.  37.  45. ... 119. 130. 135.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [  3.97709924   6.96183206  15.         ...  95.35114504 106.85496183
#  112.25954198]
# shape train
# (65536,)
# [102. 100.  86. ...  52.  52.  53.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [71.97709924 69.96183206 56.         ... 28.35114504 28.85496183
#  30.25954198]
# shape train
# (65536,)
# [84. 84. 83. ... 19. 14.  7.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [ 53.97709924  53.96183206  53.         ...  -4.64885496  -9.14503817
#  -15.74045802]
# shape train
# (65536,)
# [133. 128. 117. ... 199. 200. 195.]
# shape mean face
# (65536,)
# [30.02290076 30.03816794 30.         ... 23.64885496 23.14503817
#  22.74045802]
# normalied
# [102.97709924  97.96183206  87.         ... 175.35114504 176.85496183
#  172.25954198]
